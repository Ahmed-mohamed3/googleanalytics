# %%
pip install --upgrade 'google-cloud-bigquery[bqstorage, pandas]'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os 
from google.cloud import bigquery

creds = 'gbqpy.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = creds

client = bigquery.Client()
q = (f'SELECT * From `live-training-project-359704.analytics_327675126.events_20220816` ')
query = client.query(q)
df = query.result().to_dataframe()

df
# Out:
#    event_date   event_timestamp       event_name  \
# 0    20220816  1660699285481236      first_visit
# 1    20220816  1660699285481236    session_start
# 2    20220816  1660699285481236        page_view
# 3    20220816  1660699287970198           scroll
# 4    20220816  1660699287970198  user_engagement
# ..        ...               ...              ...
# 68   20220816  1660710858112414        page_view
# 69   20220816  1660710860326891           scroll
# 70   20220816  1660710860326891  user_engagement
# 71   20220816  1660710866196773        page_view
# 72   20220816  1660710866196773           scroll
#
#                                          event_params  \
# 0   [{'key': 'ga_session_number', 'value': {'strin...
# 1   [{'key': 'ga_session_number', 'value': {'strin...
# 2   [{'key': 'page_location', 'value': {'string_va...
# 3   [{'key': 'engaged_session_event', 'value': {'s...
# 4   [{'key': 'page_referrer', 'value': {'string_va...
# ...

# %%
df_geo = df[['geo']]
df_geo = pd.json_normalize(df_geo['geo'])
df_geo
# Out:
#    continent country             region   city    sub_continent      metro
# 0     Africa   Egypt  Cairo Governorate  Cairo  Northern Africa  (not set)
# 1     Africa   Egypt  Cairo Governorate  Cairo  Northern Africa  (not set)
# 2     Africa   Egypt  Cairo Governorate  Cairo  Northern Africa  (not set)
# 3     Africa   Egypt  Cairo Governorate  Cairo  Northern Africa  (not set)
# 4     Africa   Egypt  Cairo Governorate  Cairo  Northern Africa  (not set)
# ..       ...     ...                ...    ...              ...        ...
# 68    Africa   Egypt  Cairo Governorate  Cairo  Northern Africa  (not set)
# 69    Africa   Egypt  Cairo Governorate  Cairo  Northern Africa  (not set)
# 70    Africa   Egypt  Cairo Governorate  Cairo  Northern Africa  (not set)
# 71    Africa   Egypt  Cairo Governorate  Cairo  Northern Africa  (not set)
# 72    Africa   Egypt  Cairo Governorate  Cairo  Northern Africa  (not set)
#
# [73 rows x 6 columns]

# %%
df_device = df[['device']]
df_device = pd.json_normalize(df_device['device'])
df_device
# Out:
#    category mobile_brand_name mobile_model_name mobile_marketing_name  \
# 0   desktop            Google            Chrome                  None
# 1   desktop            Google            Chrome                  None
# 2   desktop            Google            Chrome                  None
# 3   desktop            Google            Chrome                  None
# 4   desktop            Google            Chrome                  None
# ..      ...               ...               ...                   ...
# 68  desktop            Google            Chrome                  None
# 69  desktop            Google            Chrome                  None
# 70  desktop            Google            Chrome                  None
# 71  desktop            Google            Chrome                  None
# 72  desktop            Google            Chrome                  None
#
#    mobile_os_hardware_model operating_system operating_system_version  \
# ...

# %%
df_traffic = df[['traffic_source']]
df_traffic = pd.json_normalize(df_traffic['traffic_source'])
df_traffic
# Out:
#           name    medium      source
# 0   (referral)  referral  github.com
# 1   (referral)  referral  github.com
# 2   (referral)  referral  github.com
# 3   (referral)  referral  github.com
# 4   (referral)  referral  github.com
# ..         ...       ...         ...
# 68    (direct)    (none)    (direct)
# 69    (direct)    (none)    (direct)
# 70    (direct)    (none)    (direct)
# 71    (direct)    (none)    (direct)
# 72    (direct)    (none)    (direct)
#
# [73 rows x 3 columns]

# %%
df_params = df[['event_params']]
df_params = df_params.explode('event_params')
df_params = pd.json_normalize(df_params['event_params'])
df_params
# Out:
#                        key                                 value.string_value  \
# 0        ga_session_number                                               None
# 1               page_title                                            Welcome
# 2    engaged_session_event                                               None
# 3            page_location  https://ahmed-mohamed3.github.io/googleanalytics/
# 4            page_referrer  https://github.com/Ahmed-mohamed3/googleanalyt...
# ..                     ...                                                ...
# 715          ga_session_id                                               None
# 716      ga_session_number                                               None
# 717  engaged_session_event                                               None
# 718             page_title                                            Welcome
# 719       percent_scrolled                                               None
#
# ...

# %%
df_user_ltv = df[['user_ltv' ]]
df_user_ltv = pd.json_normalize(df_user_ltv['user_ltv'])
df_user_ltv
# Out:
#     revenue currency
# 0       0.0      USD
# 1       0.0      USD
# 2       0.0      USD
# 3       0.0      USD
# 4       0.0      USD
# ..      ...      ...
# 68      0.0      USD
# 69      0.0      USD
# 70      0.0      USD
# 71      0.0      USD
# 72      0.0      USD
#
# [73 rows x 2 columns]

# %%
df_privacy_info = df[['privacy_info' ]]
df_privacy_info = pd.json_normalize(df_privacy_info['privacy_info'])
df_privacy_info
# Out:
#    analytics_storage ads_storage uses_transient_token
# 0               None        None                   No
# 1               None        None                   No
# 2               None        None                   No
# 3               None        None                   No
# 4               None        None                   No
# ..               ...         ...                  ...
# 68              None        None                   No
# 69              None        None                   No
# 70              None        None                   No
# 71              None        None                   No
# 72              None        None                   No
#
# [73 rows x 3 columns]
